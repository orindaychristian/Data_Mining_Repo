# %% [markdown]
# <h1>DATA ANALYTICS PROJECT</h1>
# <h2>UNITED KINGDOM ROAD ACCIDENT DATA ANALYSIS</h2>
# <h3>INCLUSIVE YEARS: 2019-2022</h3>
# <h4>IMPORTING LIBRARIES</h4>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from scipy.stats import f_oneway
warnings.filterwarnings('ignore')

# %%
lamok = pd.read_csv("dengue.csv")

# %%
lamok
# Out:
#           Month  Year    Region  Dengue_Cases  Dengue_Deaths
# 0       January  2016  Region I           705              1
# 1      February  2016  Region I           374              0
# 2         March  2016  Region I           276              0
# 3         April  2016  Region I           240              2
# 4           May  2016  Region I           243              1
# ...         ...   ...       ...           ...            ...
# 1015     August  2020     BARMM            91              0
# 1016  September  2020     BARMM            16              8
# 1017    October  2020     BARMM            13              9
# 1018   November  2020     BARMM            15              1
# 1019   December  2020     BARMM            23              0
#
# [1020 rows x 5 columns]

# %% [markdown]
# <h1>INSIGHT 1</h1>
# <h2>WHICH YEAR RECORDED THE HIGHEST NUMBER OF DENGUE CASES?</h2>
# <h3>THE YEAR RECORDED THE HIGHEST NUMBER OF DENGUE CASES IS 2019</h3>

# %%
lamok.groupby('Year')['Dengue_Cases'].sum()

yearly_cases = lamok.groupby('Year')['Dengue_Cases'].sum()
plt.figure(figsize=(10,5))
plt.plot(yearly_cases.index, yearly_cases.values, marker='o', linestyle='-', color='blue', label="Dengue")
plt.xlabel('Year')
plt.ylabel('Total Dengue Cases')
plt.title('Total Dengue Cases Per Year')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# <h1>INSIGHT 2</h1>
# <h2>WHICH YEAR RECORDED THE LOWEST NUMBER OF DENGUE CASES?</h2>
# <h3>THE LOWEST NUMBER OF DENGUE CASES IN YEAR IS 2020</h3>

# %%
lamok.groupby('Year')['Dengue_Cases'].sum()

yearly_cases = lamok.groupby('Year')['Dengue_Cases'].sum()
plt.figure(figsize=(10,5))
plt.plot(yearly_cases.index, yearly_cases.values, marker='o', linestyle='-', color='blue', label="Dengue")
plt.xlabel('Year')
plt.ylabel('Total Dengue Cases')
plt.title('Total Dengue Cases Per Year')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# <h1>INSIGHT 3</h1>
# <h2>IN WHICH MONTH HAS THE LOWEST NUMBER OF DENGUE CASES?</h2>
# <h3>THE LOWEST NUMBER OF DENGUE CASES IN MONTH IS MAY</h3>

# %%
lamok.groupby('Month')['Dengue_Cases'].mean()

monthly_cases = lamok.groupby('Month')['Dengue_Cases'].mean()
plt.figure(figsize=(10,5))
plt.plot(monthly_cases.index, monthly_cases.values, marker='o', linestyle='-', color='blue', label="Dengue")
plt.xlabel('Month')
plt.ylabel('Total Dengue Cases')
plt.title('Total Dengue Per Month')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# <h2>INSIGHT 4</h2>
# <h3>WHICH MONTH RECORDED THE HIGHEST NUMBER OF DENGUE DEATHS?</h3>
# <h4>THE HIGHEST NUMBER OF DENGUE DEATHS IS OCTOBER</h4>

# %%
lamok.groupby('Month')['Dengue_Deaths'].mean()

monthly_cases = lamok.groupby('Month')['Dengue_Deaths'].mean()
plt.figure(figsize=(10,5))
plt.plot(yearly_cases.index, monthly_cases.values, marker='o', linestyle='-', color='blue', label="Dengue")
plt.xlabel('Month')
plt.ylabel('Total Dengue Deaths')
plt.title('Total Dengue Deaths Per Month')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# <h1>INSIGHT 5</h1>
# <h2>WHICH MONTH RECORDED THE HIGHEST NUMBER OF DENGUE CASES?</h2>
# <h3>THE HIGHEST NUMBER OF DENGUE CASES IN MONTH IS AUGUST</h3>

# %%
lamok.groupby('Month')['Dengue_Cases'].sum()

monthly_cases = lamok.groupby('Month')['Dengue_Cases'].mean()
plt.figure(figsize=(10,5))
plt.plot(monthly_cases.index, monthly_cases.values, marker='o', linestyle='-', color='blue', label="Dengue")
plt.xlabel('Month')
plt.ylabel('Total Dengue Cases')
plt.title('Total Dengue Cases Per Month')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# <h1>INSIGHT 6</h1>
# <h2>Which MONTH RECORDED THE LOWEST NUMBER OF DENGUE DEATH?</h2>
# <h3>THE LOWEST NUMBER OF DENGUE DEATH IN MONTH IS MAY</h3>

# %%
lamok.groupby('Month')['Dengue_Deaths'].mean()

yearly_cases = lamok.groupby('Month')['Dengue_Deaths'].mean()
plt.figure(figsize=(10,5))
plt.plot(yearly_cases.index, yearly_cases.values, marker='o', linestyle='-', color='blue', label="Dengue")
plt.xlabel('Month')
plt.ylabel('Total Dengue Deaths')
plt.title('Total Dengue Deaths Per Month')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# <h1>INSIGHT 7</h1>
# <h2>WHICH REGION RECORDED THE HIGHEST NUMBER OF DENGUE CASES?</h2>
# <h3>THE HIGHEST NUMBER OF DENGUE CASES IN REGION IS REGION IV-A</h3>

# %%
lamok.groupby('Region')['Dengue_Cases'].sum().idxmax()

region_cases = lamok.groupby('Region')['Dengue_Cases'].sum()
plt.figure(figsize=(12,6))
plt.bar(region_cases.index, region_cases.values, color='skyblue', edgecolor='black')
plt.xlabel('Region')
plt.ylabel('Total Dengue Cases')
plt.title('Total Dengue Cases by Region')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# <h1>INSIGHT 8</h1>
# <h2>WHICH REGION RECORDED THE LOWEST NUMBER OF DENGUE CASES?</h2>
# <h3>THE LOWEST NUMBER OF DENGUE CASES IN REGION IS BARMM</h3>

# %%
lamok.groupby('Region')['Dengue_Cases'].sum().idxmax()

region_cases = lamok.groupby('Region')['Dengue_Cases'].sum()
plt.figure(figsize=(12,6))
plt.bar(region_cases.index, region_cases.values, color='skyblue', edgecolor='black')
plt.xlabel('Region')
plt.ylabel('Total Dengue Cases')
plt.title('Total Dengue Cases by Region')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# <h1>INSIGHT 9</h1>
# <h2>WHAT REGION RECORDED THE HIGHEST NUMBER OF DENGUE DEATHS?</h2>
# <h3>THE HIGHEST NUMBER OF DENGUE DEATHS IS NCR</h3>

# %%
lamok.groupby('Region')['Dengue_Deaths'].sum().idxmax()

region_deaths = lamok.groupby('Region')['Dengue_Deaths'].sum()
plt.figure(figsize=(12,6))
plt.bar(region_deaths.index, region_deaths.values, color='skyblue', edgecolor='black')
plt.xlabel('Region')
plt.ylabel('Total Dengue Deaths')
plt.title('Total Dengue Deaths by Region')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# <h1>INSIGHT 10</h1>
# <h2>WHAT REGION RECORDED THE LOWEST NUMBER OF DENGUE DEATHS?</h2>
# <h3>THE LOWEST NUMBER OF DENGUE DEATHS IN REGION IS REGION IV-B</h3>

# %%
lamok.groupby('Region')['Dengue_Deaths'].sum().idxmax()

region_deaths = lamok.groupby('Region')['Dengue_Deaths'].sum()
plt.figure(figsize=(12,6))
plt.bar(region_deaths.index, region_deaths.values, color='skyblue', edgecolor='black')
plt.xlabel('Region')
plt.ylabel('Total Dengue Deaths')
plt.title('Total Dengue Deaths by Region')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# <h1>INSIGHT 11</h1>
# <h2> What is the average number of dengue cases 2016</h2>
# <h3>THE AVERAGE NUMBER OF DENGUE CASES IN 2016 is 18.3</h3>

# %%
lamok.groupby('Year')['Dengue_Cases'].sum().mean()
yearly_cases = lamok.groupby('Year')['Dengue_Cases'].sum()
plt.figure(figsize=(10, 6))
plt.pie(yearly_cases, labels=yearly_cases.index, autopct='%1.1f%%', colors=plt.cm.Paired.colors, startangle=140)
plt.title('Dengue Cases Distribution Across Years')
plt.show()

# %% [markdown]
# <h1>INSIGHT 12</h1>
# <h2>WHAT IS THE AVERAGE OF DENGUE CASES IN 2017?</h2>
# <h3>THE AVERAGE OF DENGUE CASES IN 2017 IS 13.4%</h3>

# %%
lamok.groupby('Year')['Dengue_Cases'].sum().mean()
yearly_cases = lamok.groupby('Year')['Dengue_Cases'].sum()
plt.figure(figsize=(10, 6))
plt.pie(yearly_cases, labels=yearly_cases.index, autopct='%1.1f%%', colors=plt.cm.Paired.colors, startangle=140)
plt.title('Dengue Cases Distribution Across Years')
plt.show()

# %% [markdown]
# <h1>INSIGHT 13</h1>
# <h2>WHAT AVERAGE OF DENGUE CASES IN 2018</h2>
# <h3>THE AVERAGE OF DENGUE CASES IN 2018 IS 21.9%</h3>

# %%
lamok.groupby('Year')['Dengue_Cases'].sum().mean()
yearly_cases = lamok.groupby('Year')['Dengue_Cases'].sum()
plt.figure(figsize=(10, 6))
plt.pie(yearly_cases, labels=yearly_cases.index, autopct='%1.1f%%', colors=plt.cm.Paired.colors, startangle=140)
plt.title('Dengue Cases Distribution Across Years')
plt.show()

# %% [markdown]
# <h1>INSIGHT 14</h1>
# <h2>WHAT AVERAGE OF DENGUE CASES IN 2019?</h2>
# <h3>THE AVERAGE OF DENGUE CASES IN 2019 IS 38.5%</h3>

# %%
lamok.groupby('Year')['Dengue_Cases'].sum().mean()
yearly_cases = lamok.groupby('Year')['Dengue_Cases'].sum()
plt.figure(figsize=(10, 6))
plt.pie(yearly_cases, labels=yearly_cases.index, autopct='%1.1f%%', colors=plt.cm.Paired.colors, startangle=140)
plt.title('Dengue Cases Distribution Across Years')
plt.show()

# %% [markdown]
# <h1>INSIGHT 15</h1>
# <h2>WHAT AVERAGE NUMBER OF DENGUE CASES IN 2020?</h2>
# <h3>THE AVERAGE NUMBER OF DENGUE CASES IN 2020 IS 7.9%</h3>

# %%
lamok.groupby('Year')['Dengue_Cases'].sum().mean()
yearly_cases = lamok.groupby('Year')['Dengue_Cases'].sum()
plt.figure(figsize=(10, 6))
plt.pie(yearly_cases, labels=yearly_cases.index, autopct='%1.1f%%', colors=plt.cm.Paired.colors, startangle=140)
plt.title('Dengue Cases Distribution Across Years')
plt.show()

# %% [markdown]
# <h1>INSIGHT 16</h1>
# <h2>WHAT AVERAGE NUMBER OF DENGUE DEATHS IN 2016?</h2>
# <h3>THE AVERAGE NUMBER OF DENGUE DEATHS IN 2016 IS 18.3%</h3>

# %%
lamok.groupby('Year')['Dengue_Deaths'].sum().mean()
yearly_cases = lamok.groupby('Year')['Dengue_Deaths'].sum()
plt.figure(figsize=(10, 6))
plt.pie(yearly_cases, labels=yearly_cases.index, autopct='%1.1f%%', colors=plt.cm.Paired.colors, startangle=140)
plt.title('Dengue Deaths Distribution Across Years')
plt.show()

# %% [markdown]
# <h1>INSIGHT 17</h1>
# <h2>WHAT AVERAGE NUMBER OF DENGUE DEATHS IN 2017?</h2>
# <h3>THE AVERAGE NUMBER OF DEATH IN 2017 IS 48.2%</h3>

# %%
lamok.groupby('Year')['Dengue_Deaths'].sum().mean()
yearly_cases = lamok.groupby('Year')['Dengue_Deaths'].sum()
plt.figure(figsize=(10, 6))
plt.pie(yearly_cases, labels=yearly_cases.index, autopct='%1.1f%%', colors=plt.cm.Paired.colors, startangle=140)
plt.title('Dengue Deaths Distribution Across Years')
plt.show()

# %% [markdown]
# <h1>INSIGHT 18</h1>
# <h2>WHAT AVERAGE NUMBER OF DENGUE DEATHS IN 2018?</h2>
# <h3>THE AVERAGE NUMBER OF DEATH IN 2018 IS 7.3%</h3>

# %%
lamok.groupby('Year')['Dengue_Deaths'].sum().mean()
yearly_cases = lamok.groupby('Year')['Dengue_Deaths'].sum()
plt.figure(figsize=(10, 6))
plt.pie(yearly_cases, labels=yearly_cases.index, autopct='%1.1f%%', colors=plt.cm.Paired.colors, startangle=140)
plt.title('Dengue Deaths Distribution Across Years')
plt.show()

# %% [markdown]
# <h1>INSIGHT 19</h1>
# <h2>WHAT AVERAGE NUMBER OF DENGUE DEATHS IN 2019?</h2>
# <h3>THE AVERAGE NUMBER OF DEATH IN 2019 IS 10.3%</h3>

# %%
lamok.groupby('Year')['Dengue_Deaths'].sum().mean()
yearly_cases = lamok.groupby('Year')['Dengue_Deaths'].sum()
plt.figure(figsize=(10, 6))
plt.pie(yearly_cases, labels=yearly_cases.index, autopct='%1.1f%%', colors=plt.cm.Paired.colors, startangle=140)
plt.title('Dengue Deaths Distribution Across Years')
plt.show()

# %% [markdown]
# <h1>INSIGHT 20</h1>
# <h2>WHAT AVERAGE NUMBER OF DENGUE DEATHS IN 2020?</h2>
# <h3>THE AVERAGE NUMBER OF DEATH IN 2020 IS 7.1%</h3>

# %%
lamok.groupby('Year')['Dengue_Deaths'].sum().mean()
yearly_cases = lamok.groupby('Year')['Dengue_Deaths'].sum()
plt.figure(figsize=(10, 6))
plt.pie(yearly_cases, labels=yearly_cases.index, autopct='%1.1f%%', colors=plt.cm.Paired.colors, startangle=140)
plt.title('Dengue Deaths Distribution Across Years')
plt.show()
